# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from IPython.display import display, Markdown


try:
    
    engine = create_engine("mysql+mysqlconnector://root:Tiag123!@localhost:3306/siasus")
    
    with engine.connect() as conexao:
        print("✅ Conexão com o banco 'siasus' realizada com sucesso!")
except Exception as e:
    print(f"❌ Erro fatal ao conectar ao MySQL: {e}")
    print("--- \nPOR FAVOR, VERIFIQUE SUA SENHA NA LINHA create_engine() ---")

# %% [markdown]
# ## 🧹 Etapas 1 e 2: Exploração e Limpeza (Recap)
#
# A primeira etapa da análise de dados (feita via SQL no Workbench) foi explorar os 13,1 milhões de registros carregados. Isso revelou duas grandes inconsistências:
#
# 1.  **Gênero Inválido:** 1.044.933 registros tinham `pa_sexo = '0'`.
# 2.  **CID Não Informado:** Mais de 9 milhões de registros tinham `pa_cidpri = '0000'`.
#
# A **Etapa 2 (Limpeza)** consistiu em tratar o problema mais crítico. Foi executado o seguinte comando no MySQL para corrigir os dados de gênero, conforme o enunciado ("preencher com 'Não informado'"):
#
# `UPDATE pars SET pa_sexo = 'I' WHERE pa_sexo = '0';`
#
# As análises a seguir são executadas sobre os dados **já limpos**.

# %% [markdown]
# ## 📊 Etapa 3.1: Volume e Perfil dos Procedimentos
# Análise do volume total de procedimentos por período (mês e trimestre).

# %%
try:
    display(Markdown("### Análise 3.1: Por Trimestre"))
    df_trimestre = pd.read_sql(sql_por_trimestre, engine)
    display(df_trimestre)
    
    display(Markdown("### Análise 3.1: Por Mês"))
    df_mes = pd.read_sql(sql_por_mes, engine)
    display(df_mes)
except Exception as e:
    print(f"❌ ERRO na Etapa 3.1: {e}")
